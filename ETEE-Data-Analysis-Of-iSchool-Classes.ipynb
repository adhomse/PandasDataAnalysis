# %% [markdown]
# # Data Analysis using pandas
#
# In this end-to-end example we will perform a data analysis in Python Pandas we will attempt to answer the following questions:
#
# - What percentage of the schedule are undergrad (course number 500 or lower)?
# - What undergrad classes are on Friday? or at 8AM?
#
# The iSchool schedule of classes can be found here: https://ischool.syr.edu/classes

# %%
import pandas as pd

# this turns off warning messages
import warnings
warnings.filterwarnings('ignore')

# %%
#link from which we can get the data

website = 'https://ischool.syr.edu/classes/?page=2'
data = pd.read_html(website)
data[0]
# Out:
#     Course Section  Class  Credits                               Title  \
# 0   IST343    M001  37841      3.0                     Data in Society
# 1   IST343    M002  37932      3.0                     Data in Society
# 2   IST344    M002  37613      3.0       Info Reporting & Presentation
# 3   IST344    M004  37624      3.0       Info Reporting & Presentation
# 4   IST344    M005  37628      3.0       Info Reporting & Presentation
# 5   IST344    M006  37630      3.0       Info Reporting & Presentation
# 6   IST344    M009  37671      3.0       Info Reporting & Presentation
# 7   IST344    M010  37685      3.0       Info Reporting & Presentation
# 8   IST345    M001  37625      3.0      Managing Info Systems Projects
# 9   IST345    M002  37626      3.0      Managing Info Systems Projects
# 10  IST345    M003  37652      3.0      Managing Info Systems Projects
# 11  IST346    M001  37608      3.0       Info Tech Mgmt&Administration
# 12  IST346    M002  37623      3.0       Info Tech Mgmt&Administration
# 13  IST346    M003  37821      3.0       Info Tech Mgmt&Administration
# 14  IST346    M004  37937      3.0       Info Tech Mgmt&Administration
# 15  IST349    M001  37634      3.0             Human Comp. Interaction
# 16  IST352    M001  37611      3.0       Info Analysis of Org. Systems
# 17  IST352    M003  37643      3.0       Info Analysis of Org. Systems
# 18  IST352    M004  37668      3.0       Info Analysis of Org. Systems
# 19  IST352    M006  37688      3.0       Info Analysis of Org. Systems
# 20  IST359    M001  37637      3.0       Intro to Data Base Mgmt Systs
# 21  IST359    M003  37640      3.0       Intro to Data Base Mgmt Systs
# 22  IST359    M004  37669      3.0       Intro to Data Base Mgmt Systs
# 23  IST359    M005  37689      3.0       Intro to Data Base Mgmt Systs
# 24  IST359    M006  37690      3.0       Intro to Data Base Mgmt Systs
# 25  IST359    M002  43033      3.0       Intro to Data Base Mgmt Systs
# 26  IST363    M001  37733      3.0       Advanced Front End Web Design
# 27  IST387    M001  37761      3.0       Intro to Applied Data Science
# 28  IST387    M002  37801      3.0  LAB: Intro to Applied Data Science
# 29  IST387    M003  37852      3.0  LAB: Intro to Applied Data Science
# 30  IST387    M004  41681      3.0  LAB: Intro to Applied Data Science
# 31  IST387    M005  42779      3.0  LAB: Intro to Applied Data Science
# 32  IST400    M002  37892      3.0                   Block Chain Mgmt.
# 33  IST407    M001  37879      3.0                         Data Mining
# 34  IST414    M001  37849      3.0                 Data Driven Inquiry
# 35  IST421    M001  37850      3.0           Information Visualization
# 36  IST425    M001  37622      3.0          Enterprise Risk Management
# 37  IST425    M002  37713      3.0          Enterprise Risk Management
# 38  IST442    M001  42307      3.0           Agile Project Mgmt. Meth.
# 39  IST452    M001  37629      3.0        Advanced Computer Networking
# 40  IST455    M001  42590      3.0          Enterprise IT Consultation
# 41  IST466    M002  37617      3.0        Prof Issues/Info Mgmt & Tech
# 42  IST466    M001  37621      3.0        Prof Issues/Info Mgmt & Tech
# 43  IST466    M003  37655      3.0        Prof Issues/Info Mgmt & Tech
# 44  IST466    M004  42628      3.0        Prof Issues/Info Mgmt & Tech
# 45  IST471    M001  37609      1.0      Internship in Info Mgmt & Tech
# 46  IST472    M001  37760      1.0       Coop Educ in Info Mgmt & Tech
# 47  IST486    U800  37735      3.0        Social Media in the Organiz.
# 48  IST486    U801  37736      3.0        Social Media in the Organiz.
# 49  IST486    M001  37933      3.0        Social Media in the Organiz.
#
#               Instructor(s)               Time   Day  \
# 0   Jennifer Stromer-Galley    2:00pm - 3:20pm  TuTh
# 1              Bryan Semaan  11:00am - 12:20pm  TuTh
# 2            Peggy M Takach   12:45pm - 2:05pm    MW
# 3              Bruce Kingma    3:45pm - 5:05pm    MW
# 4      Christopher Perrello   12:30pm - 1:50pm  TuTh
# 5          A Randall Wenner    5:15pm - 8:05pm     M
# 6        Eric William Young    3:30pm - 4:50pm  TuTh
# 7              Bruce Kingma   9:30am - 10:50am    MW
# 8         Robert E Campagna    5:15pm - 8:00pm     W
# 9              Daniel Cohen   9:30am - 10:50am  TuTh
# 10        Mark Andrew Borte    5:15pm - 8:05pm    Tu
# 11              Ryan Elstad   12:30pm - 1:50pm  TuTh
# 12      Timothy A Jorgensen   12:30pm - 1:50pm  TuTh
# 13    Lauren J Hardee-Chase    3:45pm - 5:05pm    MW
# 14    Lauren J Hardee-Chase   12:45pm - 2:05pm    MW
# 15       Natalie C. LoRusso   12:30pm - 1:50pm  TuTh
# 16                 vcschoon  11:00am - 12:20pm  TuTh
# 17       Alexander Corsello    5:15pm - 6:30pm    MW
# 18       Alexander Corsello   12:45pm - 2:05pm    MW
# 19       Alexander Corsello    8:00am - 9:20am  TuTh
# 20          Laurie A Ferger    2:15pm - 3:35pm    MW
# 21          Blythe Scherrer    5:00pm - 6:20pm  TuTh
# 22        Chad Aaron Harper    2:00pm - 3:20pm  TuTh
# 23                Mei Zhang    3:30pm - 4:50pm  TuTh
# 24          Laurie A Ferger   12:45pm - 2:05pm    MW
# 25          Blythe Scherrer    3:45pm - 5:05pm    MW
# 26                Nick Lyga    5:00pm - 6:20pm  TuTh
# 27          Stephen Wallace   9:30am - 10:50am    Tu
# 28                      NaN   12:30pm - 1:50pm    Th
# 29             Yatish Hegde    3:30pm - 4:50pm    Th
# 30        Amanda Darcangelo    5:00pm - 6:20pm    Th
# 31     Christopher N Dunham    5:15pm - 6:35pm     W
# 32         Phil Evangelista    5:15pm - 8:05pm     W
# 33          Stephen Wallace   12:45pm - 3:35pm     W
# 34      Melinda J Sebastian  11:00am - 12:20pm  TuTh
# 35         Joshua E Introne    2:00pm - 3:20pm  TuTh
# 36            Ann M Perkins    5:15pm - 6:35pm    MW
# 37           James Enwright    5:00pm - 6:20pm  TuTh
# 38            James Stewart    5:00pm - 7:45pm    Th
# 39         Jeffrey T Girard    6:30pm - 7:50pm  TuTh
# 40         Frank Jr Marullo    3:30pm - 4:50pm  TuTh
# 41         Brittany Johnson  11:00am - 12:20pm  TuTh
# 42             Bruce Kingma    8:00am - 9:20am    MW
# 43             Bruce Kingma   12:45pm - 2:05pm    MW
# 44         Brittany Johnson   9:30am - 10:50am  TuTh
# 45       Susan Monica Bonzi    1:00am - 1:00am   NaN
# 46       Susan Monica Bonzi  12:00am - 12:00am   NaN
# 47               Jason Ryan  12:00am - 12:00am   NaN
# 48               Jason Ryan  12:00am - 12:00am   NaN
# 49               Jason Ryan    5:00pm - 6:20pm  TuTh
#
#                            Room(s)
# 0                   Watson Theater
# 1                  Bowne Hall 306D
# 2                   Hinds Hall 111
# 3                   Hinds Hall 111
# 4                   Hinds Hall 011
# 5                   Newhouse 3 250
# 6            Hall of Languages 111
# 7                   Hinds Hall 018
# 8                   Hinds Hall 021
# 9                   Hinds Hall 111
# 10                  Hinds Hall 111
# 11                  Hinds Hall 010
# 12                  Hinds Hall 013
# 13                  Hinds Hall 013
# 14                  Hinds Hall 027
# 15                  Hinds Hall 111
# 16                  Hinds Hall 021
# 17                  Hinds Hall 111
# 18                  Hinds Hall 117
# 19                  Hinds Hall 117
# 20                  Hinds Hall 010
# 21           Hall of Languages 114
# 22  Hinds Hall 027  Hinds Hall 111
# 23                  Hinds Hall 013
# 24                  Hinds Hall 010
# 25                  Hinds Hall 027
# 26                  Hinds Hall 243
# 27       Life Science Building 001
# 28                  Hinds Hall 021
# 29                  Hinds Hall 018
# 30             LYMAN HALL ROOM 228
# 31                  Hinds Hall 013
# 32                  Hinds Hall 010
# 33                  Hinds Hall 013
# 34                  Hinds Hall 011
# 35                  Hinds Hall 013
# 36                      Slocum 104
# 37           Hall of Languages 105
# 38           Hall of Languages 215
# 39                  Hinds Hall 010
# 40                  Hinds Hall 011
# 41                  Hinds Hall 111
# 42                  Hinds Hall 243
# 43                  Hinds Hall 243
# 44                  Hinds Hall 243
# 45                             NaN
# 46                             NaN
# 47                          Online
# 48                          Online
# 49                           CH101

# %%
# To get Detatils from all 6 pages
website = 'https://ischool.syr.edu/classes/?page='
list_of_websites = []
for i in range(1,6):
    link = website + str(i)
    list_of_websites.append(link)
print(list_of_websites)
# Out:
# ['https://ischool.syr.edu/classes/?page=1', 'https://ischool.syr.edu/classes/?page=2', 'https://ischool.syr.edu/classes/?page=3', 'https://ischool.syr.edu/classes/?page=4', 'https://ischool.syr.edu/classes/?page=5']

# %%
info = pd.read_html("https://en.wikipedia.org/wiki/List_of_S%26P_500_companies")
company1 = info[0]
company1
# Out:
#     Symbol                Security SEC filings             GICS Sector  \
# 0      MMM              3M Company     reports             Industrials
# 1      ABT     Abbott Laboratories     reports             Health Care
# 2     ABBV             AbbVie Inc.     reports             Health Care
# 3     ABMD             ABIOMED Inc     reports             Health Care
# 4      ACN           Accenture plc     reports  Information Technology
# ..     ...                     ...         ...                     ...
# 500    YUM         Yum! Brands Inc     reports  Consumer Discretionary
# 501   ZBRA      Zebra Technologies     reports  Information Technology
# 502    ZBH  Zimmer Biomet Holdings     reports             Health Care
# 503   ZION           Zions Bancorp     reports              Financials
# 504    ZTS                  Zoetis     reports             Health Care
#
#                       GICS Sub Industry     Headquarters Location  \
# 0              Industrial Conglomerates       St. Paul, Minnesota
# 1                 Health Care Equipment   North Chicago, Illinois
# 2                       Pharmaceuticals   North Chicago, Illinois
# 3                 Health Care Equipment    Danvers, Massachusetts
# 4        IT Consulting & Other Services           Dublin, Ireland
# ..                                  ...                       ...
# 500                         Restaurants      Louisville, Kentucky
# 501  Electronic Equipment & Instruments    Lincolnshire, Illinois
# 502               Health Care Equipment           Warsaw, Indiana
# 503                      Regional Banks      Salt Lake City, Utah
# 504                     Pharmaceuticals  Florham Park, New Jersey
#
#     Date first added      CIK      Founded
# 0                NaN    66740         1902
# 1         1964-03-31     1800         1888
# 2         2012-12-31  1551152  2013 (1888)
# 3         2018-05-31   815094         1981
# 4         2011-07-06  1467373         1989
# ..               ...      ...          ...
# 500       1997-10-06  1041061          NaN
# 501       2019-12-23   877212         1969
# 502       2001-08-07  1136869          NaN
# 503       2001-06-22   109380          NaN
# 504       2013-06-21  1555280          NaN
#
# [505 rows x 9 columns]

# %%
company1['GICS Sector'].value_counts()
# Out:
# Information Technology    70
# Industrials               70
# Financials                66
# Consumer Discretionary    64
# Health Care               61
# Consumer Staples          33
# Real Estate               31
# Energy                    28
# Utilities                 28
# Materials                 28
# Communication Services    26
# Name: GICS Sector, dtype: int64

# %%
# let's read them all and append them to a single data frame

website = 'https://ischool.syr.edu/classes/?page='
classes = pd.DataFrame() #  (columns = ['Course','Section','ClassNo','Credits','Title','Instructor','Time','Days','Room'])

for i in range(1,6):
    link = website + str(i)
    data = pd.read_html(website  + str(i))    
    classes = classes.append(data[0], ignore_index=True)
    
classes.sample(5)
# Out:
#           0     1      2    3                              4  \
# 162  IST659  M400  41928  3.0  Data Admin Concepts & Db Mgmt
#
#                      5                 6  7               8
# 162  Chad Aaron Harper  12:00am - 8:30pm  M  Online  Online

# %%
## let's set the columns

website = 'https://ischool.syr.edu/classes/?page='
classes = pd.DataFrame() 

for i in range(1,6):
    link = website + str(i)
    data = pd.read_html(website  + str(i))    
    classes = classes.append(data[0], ignore_index=True)
    
classes.columns = ['Course','Section','ClassNo','Credits','Title','Instructor','Time','Days','Room']

classes.sample(5)
# Out:
#      Course Section  ClassNo  Credits                  Title  \
# 205  IST840    M801    41093      1.0  Practicum in Teaching
#
#                   Instructor               Time Days    Room
# 205  Jennifer Stromer-Galley  12:00am - 12:00am  NaN  Online

# %%
## this is good stuff. Let's make a function out of it for simplicity

def get_ischool_classes():
    website = 'https://ischool.syr.edu/classes/?page='
    classes = pd.DataFrame() 

    for i in range(1,6):
        link = website + str(i)
        data = pd.read_html(website  + str(i))    
        classes = classes.append(data[0], ignore_index=True)
    
    classes.columns = ['Course','Section','ClassNo','Credits','Title','Instructor','Time','Days','Room']

    return classes

# main program 
classes = get_ischool_classes()

# %%
classes
# Out:
#      Course Section  ClassNo  Credits                       Title  \
# 0    GET302    M001    37675      3.0   Global Financial Sys Arch
# 1    GET460    M001    37855      3.0    Global Technology Abroad
# 2    GET460    M002    41825      3.0    Global Technology Abroad
# 3    GET660    M001    37856      3.0    Global Technology Abroad
# 4    GET660    M002    41826      3.0    Global Technology Abroad
# ..      ...     ...      ...      ...                         ...
# 242  IST971    M400    42836      1.0  Internship in Info Studies
# 243  IST972    M001    37619      3.0      School Media Practicum
# 244  IST973    M800    37882      1.0  Internship in Info Studies
# 245  IST973    M402    37938      1.0  Internship in Info Studies
# 246  IST999    M001    37610      1.0                Dissertation
#
#                   Instructor               Time Days            Room
# 0                   vcschoon    5:00pm - 7:45pm   Tu  Hinds Hall 011
# 1              Michael Fudge  12:00am - 12:00am  NaN             NaN
# 2          Paul Brian Gandel  12:00am - 12:00am  NaN             NaN
# 3              Michael Fudge  12:00am - 12:00am  NaN             NaN
# 4          Paul Brian Gandel  12:00am - 12:00am  NaN             NaN
# ..                       ...                ...  ...             ...
# 242       Susan Monica Bonzi  12:00am - 12:00am  NaN             NaN
# 243       Patricia C Vilello  12:00am - 12:00am  NaN          Online
# 244  Rebecca Shaffer Mannion  12:00am - 12:00am  NaN             NaN
# 245  Rebecca Shaffer Mannion  12:00am - 12:00am  NaN          Online
# 246                      NaN  12:00am - 12:00am  NaN             NaN
#
# [247 rows x 9 columns]

# %%
# undergrad classes are 0-499, grad classes are 500 and up but we don't have course numbers!!!! So we must engineer them.

classes['Course'].str[0:3].sample(5)
#classes['Course'].str[0:3].sample(5)
classes['Course'].str[3:].sample(5)
# Out:
# 125    613
# 99     486
# 208    718
# 175    662
# 199    704
# Name: Course, dtype: object

# %%
# make the subject and number columns
classes['Subject'] = classes['Course'].str[0:3]
classes['Number'] = classes['Course'].str[3:]
classes.sample(5)
# Out:
#      Course Section  ClassNo  Credits                           Title  \
# 233  IST800    M001    37712      3.0                 Social Networks
# 37   IST256    M002    37890      3.0  Appl.Prog.For Information Syst
# 22   IST195    M009    41659      3.0   LAB: Information Technologies
# 216  IST719    M401    37939      3.0       Information Visualization
# 121  IST605    M001    42813      3.0  Reference& Info Literacy Svces
#
#                       Instructor               Time Days            Room  \
# 233             Joshua E Introne   9:30am - 12:15pm    M  Hinds Hall 120
# 37   Angela Usha Ramnarine-Rieks   12:45pm - 2:05pm    W  Hinds Hall 011
# 22         Lauren J Hardee-Chase  10:35am - 11:30am    F  Hinds Hall 013
# 216                Gary E Krudys  12:00am - 10:30pm   Tu  Online  Online
# 121                 LaVerne Gray    5:00pm - 7:45pm   Tu  Hinds Hall 120
#
#     Subject Number   Type
# 233     IST    800   Grad
# 37      IST    256  UGrad
# 22      IST    195  UGrad
# 216     IST    719   Grad
# 121     IST    605   Grad

# %%
# and finally we can create the column we need!
classes['Type'] = ''

classes['Type'][classes['Number'] < '500'] = 'UGrad'

classes['Type'][classes['Number'] >= '500'] = 'Grad'

classes.sample(5)
# Out:
#      Course Section  ClassNo  Credits                          Title  \
# 205  IST707    M003    37936      3.0                 Data Analytics
# 89   IST452    M001    37629      3.0   Advanced Computer Networking
# 69   IST352    M006    37688      3.0  Info Analysis of Org. Systems
# 135  IST618    M001    37673      3.0             Information Policy
# 165  IST655    M001    37734      3.0     Enterprise IT Consultation
#
#               Instructor             Time  Days            Room Subject  \
# 205             Ying Lin  2:00pm - 4:50pm     F  Hinds Hall 111     IST
# 89      Jeffrey T Girard  6:30pm - 7:50pm  TuTh  Hinds Hall 010     IST
# 69    Alexander Corsello  8:00am - 9:20am  TuTh  Hinds Hall 117     IST
# 135  Melinda J Sebastian  2:00pm - 4:45pm    Th  Hinds Hall 111     IST
# 165      Ingrid Erickson  2:00pm - 4:45pm    Tu  Hinds Hall 216     IST
#
#     Number   Type
# 205    707   Grad
# 89     452  UGrad
# 69     352  UGrad
# 135    618   Grad
# 165    655   Grad

# %%
# the entire program to retrieve the data and setup the columns looks like this:

# main program 
classes = get_ischool_classes()
classes['Subject'] = classes['Course'].str[0:3]
classes['Number'] = classes['Course'].str[3:]
classes['Type'] = ''
classes['Type'][classes['Number'] < '500'] = 'UGrad'
classes['Type'][classes['Number'] >= '500'] = 'Grad'

# %%
# let's fins the number of grad / undergrad courses
classes['Type'].value_counts()

# more grad classes than undergrad
# Out:
# Grad     149
# UGrad     98
# Name: Type, dtype: int64

# %%
#how many Graded classes on Monday

monday = classes[ (classes['Type'] == 'Grad') & (classes['Days'].str.find('F')>=0 ) ]
monday
# Out:
# Empty DataFrame
# Columns: [Course, Section, ClassNo, Credits, Title, Instructor, Time, Days, Room, Subject, Number, Type]
# Index: []

# %%
# how many undergrad classes on a Friday?
friday = classes[ (classes['Type'] == 'UGrad') & (classes['Days'].str.find('F')>=0 ) ]
friday
# Out:
#      Course Section  ClassNo  Credits                              Title  \
# 6    IDS403    M001    37649      1.0                    Startup Sandbox
# 7    IDS460    M002    37755      3.0                    Entretech - NYC
# 8    IDS460    M003    37756      3.0     Spring Break in Silicon Valley
# 15   IST195    M003    37658      3.0      LAB: Information Technologies
# 16   IST195    M004    37659      3.0      LAB: Information Technologies
# 17   IST195    M005    37660      3.0      LAB: Information Technologies
# 18   IST195    M006    37661      3.0      LAB: Information Technologies
# 19   IST195    M007    37662      3.0      LAB: Information Technologies
# 20   IST195    M008    37667      3.0      LAB: Information Technologies
# 21   IST195    M002    37695      3.0      LAB: Information Technologies
# 22   IST195    M009    41659      3.0      LAB: Information Technologies
# 23   IST195    M010    41832      3.0      LAB: Information Technologies
# 26   IST233    M003    37663      3.0  LAB: Intro to Computer Networking
# 27   IST233    M004    37664      3.0  LAB: Intro to Computer Networking
# 28   IST233    M005    37665      3.0  LAB: Intro to Computer Networking
# 29   IST233    M006    37666      3.0  LAB: Intro to Computer Networking
# 49   IST337    M001    37848      1.0             IM&T Support Practicum
# 100  IST486    M002    42625      3.0       Social Media in the Organiz.
#
#                   Instructor               Time       Days  \
# 6          John DuRoss Liddy    2:15pm - 5:05pm          F
# 7          John DuRoss Liddy  12:00am - 12:00am    MTuWThF
# 8          John DuRoss Liddy  12:00am - 12:00am  MTuWThFSu
# 15                Jeff Rubin   9:30am - 10:25am          F
# 16                Jeff Rubin  10:35am - 11:30am          F
# 17                Jeff Rubin  11:40am - 12:35pm          F
# 18                Jeff Rubin   12:45pm - 1:40pm          F
# 19                Jeff Rubin    1:50pm - 2:45pm          F
# 20                Jeff Rubin    2:55pm - 3:50pm          F
# 21                Jeff Rubin    8:25am - 9:20am          F
# 22     Lauren J Hardee-Chase  10:35am - 11:30am          F
# 23     Lauren J Hardee-Chase  11:40am - 12:35pm          F
# 26          S Bruce Boardman  10:35am - 11:30am          F
# 27          S Bruce Boardman  11:40am - 12:35pm          F
# 28          S Bruce Boardman   12:45pm - 1:40pm          F
# 29          S Bruce Boardman    1:50pm - 2:45pm          F
# 49             Jeffrey Fouts    2:15pm - 5:00pm          F
# 100  Kristy Lee Hochenberger   9:30am - 10:25am        MWF
#
#                                                Room Subject Number   Type
# 6                        Syracuse Technology Garden     IDS    403  UGrad
# 7     Courtyard Marriott Man Midtwn  Online  Online     IDS    460  UGrad
# 8    Online  Online  Residence Inn by Marr, San Mat     IDS    460  UGrad
# 15                                   Hinds Hall 010     IST    195  UGrad
# 16                                   Hinds Hall 010     IST    195  UGrad
# 17                                   Hinds Hall 010     IST    195  UGrad
# 18                                   Hinds Hall 010     IST    195  UGrad
# 19                                   Hinds Hall 010     IST    195  UGrad
# 20                                   Hinds Hall 010     IST    195  UGrad
# 21                                   Hinds Hall 010     IST    195  UGrad
# 22                                   Hinds Hall 013     IST    195  UGrad
# 23                                   Hinds Hall 013     IST    195  UGrad
# 26                                   Hinds Hall 027     IST    233  UGrad
# 27                                   Hinds Hall 027     IST    233  UGrad
# 28                                   Hinds Hall 027     IST    233  UGrad
# 29                                   Hinds Hall 027     IST    233  UGrad
# 49                                   Hinds Hall 117     IST    337  UGrad
# 100                                  Hinds Hall 021     IST    486  UGrad

# %%
# let's get rid of those pesky LAB sections!!!
# how many undergrad classes on a Friday?
friday_no_lab = friday[ ~friday['Title'].str.startswith('LAB:')]
friday_no_lab
# Out:
#     Course Section  ClassNo  Credits                           Title  \
# 3   GET400    M002    37081      3.0    Global Consulting Challenges
# 11  IDS402    M001    37004      3.0                    Idea2Startup
# 12  IDS403    M001    37002      1.0                 Startup Sandbox
# 13  IDS403    M002    41254      1.0                 Startup Sandbox
# 31  IST256    M001    40238      3.0  Appl.Prog.For Information Syst
# 41  IST335    M002    36937      3.0  Intro/Info Based Organizations
#
#                                            Instructor               Time Days  \
# 3                                       Jason Dedrick   10:35am - 1:10pm    F
# 11                                Michael A D'Eredita   9:30am - 12:15pm    F
# 12                                  John DuRoss Liddy  10:00am - 12:50pm    F
# 13                                  John DuRoss Liddy    1:00pm - 3:50pm    F
# 31  Michael Fudge  Avinash Kadaji  Deborah L Nosky...    8:00am - 9:20am   WF
# 41                                Michael A D'Eredita   12:45pm - 2:05pm   WF
#
#                           Room Subject Number   Type
# 3               Hinds Hall 018     GET    400  UGrad
# 11              Hinds Hall 011     IDS    402  UGrad
# 12  Syracuse Technology Garden     IDS    403  UGrad
# 13  Syracuse Technology Garden     IDS    403  UGrad
# 31    School of Management 007     IST    256  UGrad
# 41              Hinds Hall 011     IST    335  UGrad

# %%
# Looking for more classes to avoid? How about 8AM classes?
eight_am = classes[ classes['Time'].str.startswith('8:00am')]
eight_am
# Out:
#     Course Section  ClassNo  Credits                           Title  \
# 4   GET433    M001    37075      3.0     Multi-tier App. Development
# 31  IST256    M001    40238      3.0  Appl.Prog.For Information Syst
# 33  IST263    M003    37015      3.0             Web Design and Mgmt
# 34  IST263    M002    37017      3.0             Web Design and Mgmt
# 54  IST352    M005    37068      3.0   Info Analysis of Org. Systems
# 55  IST352    M006    37069      3.0   Info Analysis of Org. Systems
# 58  IST359    M003    36986      3.0   Intro to Data Base Mgmt Systs
#
#                                            Instructor             Time  Days  \
# 4                                     P Douglas Taber  8:00am - 9:20am  TuTh
# 31  Michael Fudge  Avinash Kadaji  Deborah L Nosky...  8:00am - 9:20am    WF
# 33                                   Joseph E Flateau  8:00am - 9:20am    MW
# 34                             Christian A Kirkegaard  8:00am - 9:20am  TuTh
# 54                                 Alexander Corsello  8:00am - 9:20am    MW
# 55                                 Alexander Corsello  8:00am - 9:20am  TuTh
# 58                                    Deborah L Nosky  8:00am - 9:20am  TuTh
#
#                               Room Subject Number   Type
# 4                   Hinds Hall 013     GET    433  UGrad
# 31        School of Management 007     IST    256  UGrad
# 33                  Hinds Hall 021     IST    263  UGrad
# 34                  Hinds Hall 018     IST    263  UGrad
# 54                  Hinds Hall 111     IST    352  UGrad
# 55                  Hinds Hall 117     IST    352  UGrad
# 58  Hinds Hall 010  Hinds Hall 111     IST    359  UGrad
